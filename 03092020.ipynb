# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## Problem 1
#
# Plot sin(x)

# %%
x= np.linspace(-5, 5)
y= np.sin(x)
plt.plot(x,y)
plt.show()

# %% [markdown]
# ## Problem 2
#
# Pefrom some matrix multiplication

# %%
a= np.array([[4,2],
             [0,1]])
b= np.array([[2,1],
             [3,2]])
np.matmul(a, b)
# Out:
# array([[14,  8],
#        [ 3,  2]])
